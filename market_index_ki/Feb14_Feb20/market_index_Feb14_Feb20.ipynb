# %%
import pandas as pd

# %%
df = pd.read_csv("KOSPI.csv")

# %%
df
# Out:
#                 Time     Open  Yesterday   Diff       MKT
# 0   2018-02-20 15:30  2413.97    2442.82 -28.85 -1.181012
# 1   2018-02-20 15:20  2413.41    2442.82 -29.41 -1.203936
# 2   2018-02-20 15:10  2411.63    2442.82 -31.19 -1.276803
# 3   2018-02-20 15:00  2413.09    2442.82 -29.73 -1.217036
# 4   2018-02-20 14:50  2413.36    2442.82 -29.46 -1.205983
# 5   2018-02-20 14:40  2415.32    2442.82 -27.50 -1.125748
# 6   2018-02-20 14:30  2418.63    2442.82 -24.19 -0.990249
# 7   2018-02-20 14:20  2420.33    2442.82 -22.49 -0.920657
# 8   2018-02-20 14:10  2422.36    2442.82 -20.46 -0.837557
# 9   2018-02-20 14:00  2423.04    2442.82 -19.78 -0.809720
# 10  2018-02-20 13:50  2425.04    2442.82 -17.78 -0.727847
# 11  2018-02-20 13:40  2425.72    2442.82 -17.10 -0.700011
# 12  2018-02-20 13:30  2423.03    2442.82 -19.79 -0.810129
# 13  2018-02-20 13:20  2420.38    2442.82 -22.44 -0.918610
# 14  2018-02-20 13:10  2423.51    2442.82 -19.31 -0.790480
# ...

# %%
diction = {}

# %%
for idx, row in df.iterrows():
    diction[row["Time"]] = row["MKT"]

# %%
diction
# Out:
# {'2018-02-14 09:00': 0.7214458979999999,
#  '2018-02-14 09:10': 0.8521244659999999,
#  '2018-02-14 09:20': 0.690133142,
#  '2018-02-14 09:30': 0.62876014,
#  '2018-02-14 09:40': 0.829996785,
#  '2018-02-14 09:50': 1.231217565,
#  '2018-02-14 10:00': 1.188632217,
#  '2018-02-14 10:10': 0.7368935240000001,
#  '2018-02-14 10:20': 0.949402761,
#  '2018-02-14 10:30': 0.9322851209999999,
#  '2018-02-14 10:40': 0.9126624609999999,
#  '2018-02-14 10:50': 1.0441760359999999,
#  '2018-02-14 11:00': 0.992823116,
#  '2018-02-14 11:10': 0.850871956,
#  '2018-02-14 11:20': 0.723533415,
#  '2018-02-14 11:30': 0.734806007,
#  '2018-02-14 11:40': 0.6930556659999999,
#  '2018-02-14 11:50': 0.68136557,
#  '2018-02-14 12:00': 0.588262309,
#  '2018-02-14 12:10': 0.579494737,
#  '2018-02-14 12:20': 0.71309583,
#  '2018-02-14 12:30': 0.7151833470000001,
#  '2018-02-14 12:40': 0.817471683,
#  '2018-02-14 12:50': 0.7122608229999999,
#  '2018-02-14 13:00': 0.666335447,
#  '2018-02-14 13:10': 0.675938026,
# ...

# %%
'''
import json
json = json.dumps(diction, ensure_ascii=False)
f = open("KOSPI_Feb14_Feb20.json","w")
f.write(json)
f.close()
'''
